# %% [markdown]
# # MetaCAT - Training biLSTM

# %%
import numpy as np
from tokenizers import ByteLevelBPETokenizer
from pathlib import Path
from medcat.meta_cat import MetaCAT
from medcat.preprocessing.tokenizers import TokenizerWrapperBPE

# %%
# Input
data_dir = Path.cwd().parents[0] / 'data'
annotation_file = data_dir / 'emc-dcc_ann.json'

# Output
model_dir = Path.cwd().parents[0] / 'models' / 'bilstm'
embeddings_file = model_dir / 'embeddings.npy'

# Name should contain 'bbpe' for ByteLevelBPETokenizer or 'bert' for BertTokenizerFast
# This name is saved in the model_config dict and subssequently in vars.dat on disk.
tokenizer_name = 'bbpe_dutch-wikipedia'

# %% [markdown]
# ## Load Tokenizer and embeddings matrix

# %%
tokenizer = TokenizerWrapperBPE.load(model_dir, tokenizer_name)
embeddings = np.load(embeddings_file)

# %% [markdown]
# ## Train biLSTM

# %%
from medcat.meta_cat import MetaCAT

# Initiate MetaCAT
mc_negation = MetaCAT(tokenizer=tokenizer,
                      embeddings=embeddings,
                      pad_id=len(embeddings)-1,
                      save_dir=model_dir,
                      device='cpu')

# Train model
results = mc_negation.train(annotation_file, 
                            'Negation',
                            nepochs=10,
                            model_config={'tokenizer_name': tokenizer_name})
# Out:
# Epoch: 0 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.85      0.69      0.76      1591
#            1       0.95      0.98      0.97      9758
#
#     accuracy                           0.94     11349
#    macro avg       0.90      0.84      0.86     11349
# weighted avg       0.94      0.94      0.94     11349
#
# Epoch: 0 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84       182
#            1       0.96      0.99      0.97      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.93      0.88      0.91      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.19756084363776402
# Test Loss:  0.15934789850143716
#
#
#
#
#
#
# ==================================================
# Model saved at epoch: 0 and f1: 0.955060714508799
# [[ 142   40]
#  [  15 1065]]
#
#
#
# Epoch: 1 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84      1591
#            1       0.96      0.99      0.98      9758
#
#     accuracy                           0.96     11349
#    macro avg       0.94      0.88      0.91     11349
# weighted avg       0.96      0.96      0.96     11349
#
# Epoch: 1 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83       182
#            1       0.96      0.99      0.97      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.94      0.88      0.90      1262
# weighted avg       0.96      0.96      0.95      1262
#
# Train Loss: 0.15403218908747002
# Test Loss:  0.15522880345815793
#
#
#
#
#
#
# Epoch: 2 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.96     11349
#    macro avg       0.94      0.89      0.91     11349
# weighted avg       0.96      0.96      0.96     11349
#
# Epoch: 2 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84       182
#            1       0.96      0.99      0.97      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.93      0.88      0.91      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.14671796105119964
# Test Loss:  0.17089527027565055
#
#
#
#
#
#
# Epoch: 3 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.96     11349
#    macro avg       0.95      0.89      0.92     11349
# weighted avg       0.96      0.96      0.96     11349
#
# Epoch: 3 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83       182
#            1       0.96      0.99      0.97      1080
#
#     accuracy                           0.95      1262
#    macro avg       0.93      0.88      0.90      1262
# weighted avg       0.95      0.95      0.95      1262
#
# Train Loss: 0.1442460693143518
# Test Loss:  0.15835736726876348
#
#
#
#
#
#
# Epoch: 4 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.96     11349
#    macro avg       0.95      0.90      0.92     11349
# weighted avg       0.96      0.96      0.96     11349
#
# Epoch: 4 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85       182
#            1       0.97      0.99      0.98      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.93      0.89      0.91      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.13034873405425534
# Test Loss:  0.15122665878152475
#
#
#
#
#
#
# ==================================================
# Model saved at epoch: 4 and f1: 0.9569197378801325
# [[ 145   37]
#  [  16 1064]]
#
#
#
# Epoch: 5 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.96     11349
#    macro avg       0.95      0.90      0.92     11349
# weighted avg       0.96      0.96      0.96     11349
#
# Epoch: 5 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84       182
#            1       0.96      0.99      0.98      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.94      0.88      0.91      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.12737087376783013
# Test Loss:  0.16204759030370042
#
#
#
#
#
#
# Epoch: 6 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.87      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.97     11349
#    macro avg       0.95      0.91      0.93     11349
# weighted avg       0.97      0.97      0.97     11349
#
# Epoch: 6 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86       182
#            1       0.97      0.99      0.98      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.95      0.90      0.92      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.11824824986733418
# Test Loss:  0.1785205775668146
#
#
#
#
#
#
# ==================================================
# Model saved at epoch: 6 and f1: 0.960831710472803
# [[ 146   36]
#  [  12 1068]]
#
#
#
# Epoch: 7 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.96     11349
#    macro avg       0.95      0.90      0.92     11349
# weighted avg       0.96      0.96      0.96     11349
#
# Epoch: 7 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85       182
#            1       0.96      0.99      0.98      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.94      0.89      0.91      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.1280558835764245
# Test Loss:  0.14489431542460807
#
#
#
#
#
#
# Epoch: 8 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.97     11349
#    macro avg       0.95      0.90      0.93     11349
# weighted avg       0.97      0.97      0.96     11349
#
# Epoch: 8 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.84       182
#            1       0.96      0.99      0.98      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.94      0.88      0.91      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.1262961089263447
# Test Loss:  0.1547165178344585
#
#
#
#
#
#
# Epoch: 9 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1591
#            1       0.97      0.99      0.98      9758
#
#     accuracy                           0.96     11349
#    macro avg       0.94      0.91      0.92     11349
# weighted avg       0.96      0.96      0.96     11349
#
# Epoch: 9 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85       182
#            1       0.97      0.99      0.98      1080
#
#     accuracy                           0.96      1262
#    macro avg       0.94      0.89      0.91      1262
# weighted avg       0.96      0.96      0.96      1262
#
# Train Loss: 0.12192936366240323
# Test Loss:  0.14927227824227884
#
#
#
#
#
#
# Best/Average scores: F1: 0.960831710472803, P: 0.9611409064069141, R: 0.9619651347068146

# %% [markdown]
# ## Save model

# %%
# Save model config
mc_negation.save(full_save=False)
