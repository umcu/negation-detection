# %% [markdown]
# # MetaCAT - Training biLSTM

# %%
import numpy as np
from pathlib import Path
from medcat.meta_cat import MetaCAT
from medcat.config_meta_cat import ConfigMetaCAT
from medcat.tokenizers.meta_cat_tokenizers import TokenizerWrapperBPE

# %%
# Input & output
data_dir = Path.cwd().parents[0] / 'data'
annotation_file = data_dir / 'emc-dcc_ann.json'
model_dir = Path.cwd().parents[0] / 'models' / 'bilstm'
embeddings_file = model_dir / 'embeddings.npy'

# Config
config_metacat = ConfigMetaCAT()
config_metacat.general['category_name'] = 'Negation'
config_metacat.train['nepochs'] = 10

# %% [markdown]
# ## Load Tokenizer and embeddings matrix

# %%
tokenizer = TokenizerWrapperBPE.load(model_dir)
embeddings = np.load(embeddings_file)

# %% [markdown]
# ## Train biLSTM

# %%
# Initiate MetaCAT
mc_negation = MetaCAT(tokenizer=tokenizer, embeddings=embeddings, config=config_metacat)

# %%
# Train model
results = mc_negation.train(json_path=annotation_file, save_dir_path=model_dir)
# Out:
# Epoch: 0 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.76      1569
#            1       0.95      0.98      0.96      9727
#
#     accuracy                           0.94     11296
#    macro avg       0.90      0.83      0.86     11296
# weighted avg       0.94      0.94      0.94     11296
#
# Epoch: 0 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       191
#            1       0.98      0.99      0.98      1064
#
#     accuracy                           0.97      1255
#    macro avg       0.95      0.93      0.94      1255
# weighted avg       0.97      0.97      0.97      1255
#
#
# ##### Model saved to /Users/stan3/Data/negation-detection/models/bilstm/model.dat at epoch: 0 and f1: 0.9702243284980442 #####
#
# Epoch: 1 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      1569
#            1       0.98      0.99      0.99      9727
#
#     accuracy                           0.98     11296
#    macro avg       0.96      0.94      0.95     11296
# weighted avg       0.98      0.98      0.98     11296
#
# Epoch: 1 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       191
#            1       0.99      0.98      0.98      1064
#
#     accuracy                           0.97      1255
#    macro avg       0.95      0.95      0.95      1255
# weighted avg       0.97      0.97      0.97      1255
#
#
# ##### Model saved to /Users/stan3/Data/negation-detection/models/bilstm/model.dat at epoch: 1 and f1: 0.9737890655863939 #####
#
# Epoch: 2 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94      1569
#            1       0.99      0.99      0.99      9727
#
#     accuracy                           0.98     11296
#    macro avg       0.97      0.96      0.97     11296
# weighted avg       0.98      0.98      0.98     11296
#
# Epoch: 2 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.89       191
#            1       0.97      1.00      0.98      1064
#
#     accuracy                           0.97      1255
#    macro avg       0.98      0.91      0.94      1255
# weighted avg       0.97      0.97      0.97      1255
#
# Epoch: 3 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      1569
#            1       0.99      1.00      0.99      9727
#
#     accuracy                           0.99     11296
#    macro avg       0.98      0.98      0.98     11296
# weighted avg       0.99      0.99      0.99     11296
#
# Epoch: 3 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90       191
#            1       0.97      0.99      0.98      1064
#
#     accuracy                           0.97      1255
#    macro avg       0.97      0.92      0.94      1255
# weighted avg       0.97      0.97      0.97      1255
#
# Epoch: 4 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1569
#            1       0.99      0.99      0.99      9727
#
#     accuracy                           0.99     11296
#    macro avg       0.98      0.98      0.98     11296
# weighted avg       0.99      0.99      0.99     11296
#
# Epoch: 4 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94       191
#            1       0.99      0.99      0.99      1064
#
#     accuracy                           0.98      1255
#    macro avg       0.96      0.96      0.96      1255
# weighted avg       0.98      0.98      0.98      1255
#
#
# ##### Model saved to /Users/stan3/Data/negation-detection/models/bilstm/model.dat at epoch: 4 and f1: 0.980143231504844 #####
#
# Epoch: 5 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1569
#            1       1.00      1.00      1.00      9727
#
#     accuracy                           0.99     11296
#    macro avg       0.99      0.99      0.99     11296
# weighted avg       0.99      0.99      0.99     11296
#
# Epoch: 5 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.98      0.83      0.90       191
#            1       0.97      1.00      0.98      1064
#
#     accuracy                           0.97      1255
#    macro avg       0.98      0.91      0.94      1255
# weighted avg       0.97      0.97      0.97      1255
#
# Epoch: 6 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1569
#            1       1.00      1.00      1.00      9727
#
#     accuracy                           0.99     11296
#    macro avg       0.99      0.99      0.99     11296
# weighted avg       0.99      0.99      0.99     11296
#
# Epoch: 6 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       191
#            1       0.98      0.99      0.99      1064
#
#     accuracy                           0.98      1255
#    macro avg       0.97      0.95      0.96      1255
# weighted avg       0.98      0.98      0.98      1255
#
# Epoch: 7 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1569
#            1       1.00      1.00      1.00      9727
#
#     accuracy                           1.00     11296
#    macro avg       0.99      0.99      0.99     11296
# weighted avg       1.00      1.00      1.00     11296
#
# Epoch: 7 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       191
#            1       0.99      0.99      0.99      1064
#
#     accuracy                           0.98      1255
#    macro avg       0.96      0.96      0.96      1255
# weighted avg       0.98      0.98      0.98      1255
#
# Epoch: 8 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1569
#            1       1.00      1.00      1.00      9727
#
#     accuracy                           1.00     11296
#    macro avg       0.99      0.99      0.99     11296
# weighted avg       1.00      1.00      1.00     11296
#
# Epoch: 8 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       191
#            1       0.98      1.00      0.99      1064
#
#     accuracy                           0.98      1255
#    macro avg       0.97      0.93      0.95      1255
# weighted avg       0.98      0.98      0.97      1255
#
# Epoch: 9 **************************************************  Train
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1569
#            1       1.00      1.00      1.00      9727
#
#     accuracy                           1.00     11296
#    macro avg       0.99      0.99      0.99     11296
# weighted avg       1.00      1.00      1.00     11296
#
# Epoch: 9 **************************************************  Test
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       191
#            1       0.99      0.98      0.99      1064
#
#     accuracy                           0.98      1255
#    macro avg       0.95      0.97      0.96      1255
# weighted avg       0.98      0.98      0.98      1255
